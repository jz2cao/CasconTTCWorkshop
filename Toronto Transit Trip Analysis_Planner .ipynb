# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='ff004a4c-4409-4f7c-903d-0ca86ded3f9e', project_access_token='p-99c29cc0d779eec38c777a54977c121b3d041679')
pc = project.project_context

# %%
# Import Data 
# Concatenate Dataframes
# Delete Vehicle and code columns
# Look for NaN, Undefined, or missing values. Edit them by removal or fill them in.
# Make sure all values are uniform. 
# Seperate Date into Month Day columns and delete Date 

# Visualize the data to understand it better
# Statistically analyze data to confirm visualizations and understand import features
# Feature Engineering ?

## Put this off until we do some visualization and Statistical analysis
# Hot encode Day 
# Hot Encode Station
# Hot Encode Bound 
# Hot encode line 

# Import ttc data from db2 on watson cloud 
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_63e2db6b97f04abbb0b75b59611a0395 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='MGeFU5EULCtA6jEbJnROcmaCSxBONNvATmYPS5zs13jE',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-january-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

january = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-february-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

february = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-march-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

march = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-april-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

april = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-may-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

may = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-june-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

june = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-july-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

july = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-august-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

august = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-september-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

september = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-october-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

october = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-november-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

november = pd.read_csv(body)

body = client_63e2db6b97f04abbb0b75b59611a0395.get_object(Bucket='casconproject-donotdelete-pr-wmzosx0pmqeybg',Key='ttc-subway-delay-december-2018.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

december = pd.read_csv(body)

# %%
# This function transforms the day of the week into a number
# def toNumber(x):
#    day={"Monday":0, "Tuesday":1, "Wednesday":2, "Thursday":3, "Friday":4, "Saturday":5, "Sunday":6}
#    return day[x]

# %%
# Merge the data to get information for entire year of subway delays
ttc_2018 = pd.concat([january, february, march, april, may, june, july, august, september, october, november, december])

# Drop all missing values
ttc_2018 = ttc_2018.dropna()

# Changing the Date to separate Day and Month columns
ttc_2018['Date'] = pd.to_datetime(ttc_2018['Date'])
ttc_2018['Month'] = ttc_2018['Date'].dt.month
ttc_2018['DayOfMonth'] = ttc_2018['Date'].dt.day

# Changing the day of the week to a number
# ttc_2018["Day"]=ttc_2018["Day"].apply(toNumber)
# ttc_2018 = pd.concat([ttc_2018, pd.get_dummies(ttc_2018['Day'])], axis=1, sort=False)
# ttc_2018 = pd.concat([ttc_2018, pd.get_dummies(ttc_2018['Station'])], axis=1, sort=False)

# Drop Vehicle number and code columns 
ttc_2018 = ttc_2018.drop(['Vehicle','Code', 'Date', 'Day','Min Gap'], axis=1)#'Station'

# %%
ttc_2018['Station'].unique()
# Out:
# array(['SHEPPARD WEST STATION', 'MUSEUM STATION', 'KIPLING STATION',
#        'COLLEGE STATION', 'WARDEN STATION', 'WILSON YARD',
#        'DONLANDS STATION', 'KEELE STATION', 'KENNEDY BD STATION',
#        'KENNEDY SRT STATION', 'VICTORIA PARK STATION', 'OLD MILL STATION',
#        'DAVISVILLE STATION', 'EGLINTON WEST STATION',
#        'ROYAL YORK STATION', 'CHESTER STATION', 'COXWELL STATION',
#        'ST GEORGE BD STATION', 'SHERBOURNE STATION', 'EGLINTON STATION',
#        'PAPE STATION', 'BLOOR STATION', 'ST PATRICK STATION',
#        'CHRISTIE STATION', 'LAWRENCE EAST STATION', 'UNION STATION',
#        'MCCOWAN STATION', 'YORK MILLS STATION', 'HIGH PARK STATION',
#        'FINCH STATION', 'LESLIE STATION', 'GREENWOOD STATION',
#        'KING STATION', 'WILSON STATION', 'VAUGHAN MC STATION',
#        'MAIN STREET STATION', 'LAWRENCE STATION', "QUEEN'S PARK STATION",
#        'JANE STATION', 'DUNDAS STATION', 'ST GEORGE YUS STATION',
# ...

# %%
# import matplotlib.pyplot as plt
# weekday = ttc_2018.groupby('Day').count().reset_index()
# plt.bar(weekday['Day'], weekday['Month'])

# %%
# ttc_2018.groupby('Day').count()

# %%
credentials = {
     'IBM_API_KEY_ID': 'MGeFU5EULCtA6jEbJnROcmaCSxBONNvATmYPS5zs13jE',
     'IAM_SERVICE_ID': 'xxx',
     'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
     'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
     'BUCKET': 'casconproject-donotdelete-pr-wmzosx0pmqeybg',
     'FILE': 'final.csv'
}
     
from ibm_botocore.client import Config
import ibm_boto3

cos = ibm_boto3.client(service_name='s3',
    ibm_api_key_id=credentials['IBM_API_KEY_ID'],
    ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
    ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
    config=Config(signature_version='oauth'),
    endpoint_url=credentials['ENDPOINT'])

ttc_2018.to_csv("final.csv", encoding="utf-8")

with open('final.csv', 'rb') as data:
    cos.upload_fileobj(data,  credentials['BUCKET'], 'final.csv')

# %%
# Save dataframe as csv file to storage
project.save_data(data=ttc_2018.to_csv(index=False),file_name='final.csv',overwrite=True)
# Out:
# {'file_name': 'final.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'casconproject-donotdelete-pr-wmzosx0pmqeybg',
#  'asset_id': 'f596e50c-0d39-4e84-b47e-10c4705fc74e'}

# %%
ttc_2018
# Out:
#        Time  Min Delay Bound Line  Month  DayOfMonth  Friday  Monday  \
# 0     00:29         10     N   YU      1           1       0       1
# 2     01:22          0     N   YU      1           1       0       1
# 4     01:39          6     S   YU      1           1       0       1
# 6     02:09          3     E   BD      1           1       0       1
# 8     02:42          7     N   YU      1           1       0       1
# 10    03:06          3     E   BD      1           1       0       1
# 11    03:12          0     N   YU      1           1       0       1
# 12    04:38          0     S   YU      1           1       0       1
# 13    07:55          4     W   BD      1           1       0       1
# 14    07:57          4     W   BD      1           1       0       1
# 15    08:02          0     W   BD      1           1       0       1
# 17    08:28          4     W   BD      1           1       0       1
# 18    08:33          7     N  SRT      1           1       0       1
# ...
